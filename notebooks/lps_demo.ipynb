# %% [markdown]
# # Enhancing OGGM with Cryosat Data and Surface Tracking

# %% [markdown]
# Support for daily mass balance is not yet integrated into OGGM. Until then, install OGGM with the daily mass balance model by running:
#
# ```
# !pip install --upgrade git+https://github.com/gampnico/oggm@feat-lps
# ```
#
# In a cell below.

# %%
import datetime
import importlib
import os
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
from dateutil.tz import UTC
from dtcg.datacube import cryotempo_eolis
from oggm import cfg, tasks, utils, workflow
from oggm.core import massbalance
from oggm.shop import its_live, rgitopo, w5e5

module_path = os.path.abspath(os.path.join("../src"))
# module_path = Path("../src").resolve().as_posix()
if module_path not in sys.path:
    sys.path.append(module_path)

import oggm_scripts.plotting as oggm_plot
from oggm_scripts import datacube_calib

plt.rcParams["axes.prop_cycle"] = plt.cycler(color=plt.cm.Set1.colors)

try:
    import holoviews as hv

    hv.extension("bokeh")
except ImportError:
    pass
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4cda7314-46d2-4670-b3fc-fe7e9457122d'>
#   <div id="fb6bc8e9-eb17-423f-a53c-b9ad06ea06a6" data-root-id="4cda7314-46d2-4670-b3fc-fe7e9457122d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# # Initialisation

# %%
datacube_calib.init_oggm(tempdir="OGGM-lps-demo", reset=False)

rgi_ids = ["RGI60-06.00377"]
gdirs = datacube_calib.get_gdirs(rgi_ids=rgi_ids)

# Dyngjujoekull, Eyjabakkajoekull, Tungnaarjoekull, Koeldukvislarjoekull, Bruarjoekull
gdir = datacube_calib.get_gdir_for_calibration(gdirs, "name", "Bruarjoekull")
gdirs = [gdir]

workflow.execute_entity_task(
    rgitopo.select_dem_from_dir, gdirs, dem_source="COPDEM90", keep_dem_folders=True
)
workflow.execute_entity_task(tasks.glacier_masks, gdirs)
workflow.execute_entity_task(its_live.itslive_velocity_to_gdir, gdirs)

# add daily data
workflow.execute_entity_task(gdirs=[gdir], task=w5e5.process_w5e5_data)
workflow.execute_entity_task(gdirs=[gdir], task=w5e5.process_w5e5_data, daily=True)

# Check data exists
path_day = gdir.get_filepath("climate_historical_daily")
path_month = gdir.get_filepath("climate_historical")
for path in [path_day, path_month]:
    assert os.path.exists(path)
with utils.ncDataset(path_day) as nc_day:
    print(oggm_plot.get_bold(f"{nc_day.climate_source}:", suffix=path_day))
with utils.ncDataset(path_month) as nc_month:
    print(oggm_plot.get_bold(f"{nc_month.climate_source}:", suffix=path_month))
# Out:
# 2025-06-16 23:24:59: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2025-06-16 23:24:59: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2025-06-16 23:24:59: oggm.cfg: Multiprocessing: using all available processors (N=20)
# 2025-06-16 23:24:59: oggm.cfg: Multiprocessing switched ON after user settings.
# 2025-06-16 23:24:59: oggm.cfg: PARAMS['store_model_geometry'] changed from `False` to `True`.
# 2025-06-16 23:24:59: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2025-06-16 23:25:00: oggm.workflow: init_glacier_directories from prepro level 1 on 1 glaciers.
# 2025-06-16 23:25:00: oggm.workflow: Execute entity tasks [gdir_from_prepro] on 1 glaciers
# 2025-06-16 23:25:00: oggm.workflow: Execute entity tasks [select_dem_from_dir] on 1 glaciers
# 2025-06-16 23:25:00: oggm.workflow: Execute entity tasks [glacier_masks] on 1 glaciers
# Bruarjoekull
# ...

# %% [markdown]
# ## Retrieve EOLIS Data

# %%
# specklia_api_key = SPECKLIA_KEY
specklia_api_key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiZHRjX2dsYWNpZXJzIiwic2FsdCI6IjhkYTQ0MzZkMDY4OTE5N2YifQ.8lqP5ebcBNrJTNBnNgmSRz2QK-iaBwhrC10tDRmASlI"
os.environ["SPECKLIA_API_KEY"] = specklia_api_key

# %%
with xr.open_dataset(gdir.get_filepath("gridded_data")) as ds:
    ds = ds.load()
ds

DataCubeManager = cryotempo_eolis.DatacubeCryotempoEolis()
eolis_data = DataCubeManager.retrieve_prepare_eolis_gridded_data(
    oggm_ds=ds, grid=gdir.grid
)

# %%
fig = oggm_plot.plot_elevation_maps(gdir, ds)

# %% [markdown]
# ## Calibration

# %%
# Create flowlines from elevation bands
tasks.elevation_band_flowline(gdir=gdir, preserve_totals=True)
tasks.fixed_dx_elevation_band_flowline(gdir, preserve_totals=True)

# %% [markdown]
# ## Create reference mass balance
#
# The Specklia dataset is available in 30-day increments, so the reference period has to be adjusted to the nearest available date.

# %%
def get_nearest(items, pivot):
    return min(items, key=lambda x: abs(x - pivot))

def get_dhdt_data(ds, calendar: bool = False, year_start=2010, year_end=2020):
    """
    Parameters
    ----------
    ds : xr.DataArray
        OGGM dataset with EOLIS datacube.
    calendar : bool, default False
        Reference period is bound to calendar years. This will find the
        nearest available date to the selected first and last years.
    year_start : int
        Start of reference period.
    year_end : int
        End of reference period.
    """
    dates = datacube_calib.get_eolis_dates(ds)
    elevation = np.array(
        [
            np.nanmean(elevation_change_map.where(ds.glacier_mask == 1))
            for elevation_change_map in ds.eolis_gridded_elevation_change
        ]
    )

    if calendar:
        year_start = datetime.datetime(year_start-1, 12, 31, tzinfo=UTC)
        year_end = datetime.datetime(year_end, 1, 1, tzinfo=UTC)
        
        year_start = get_nearest(dates, year_start)
        year_end = get_nearest(dates, year_end)

        mask = (year_start <= dates) & (
        dates <= year_end
        )
        dates = dates[mask]
        elevation = elevation[mask]

    calib_frame = pd.DataFrame({"dh": elevation}, index=dates)
    # calib_frame["dh"] = calib_frame["elevation"] - calib_frame["elevation"].iloc[0]
    calib_frame["dt"] = calib_frame.index.diff()
    calib_frame["dt"] = calib_frame["dt"].astype("timedelta64[s]")
    calib_frame.loc[calib_frame.index[0], "dt"] = calib_frame["dt"].iloc[1]

    calib_frame["dhdt"] = calib_frame["dh"] / calib_frame["dt"].values.astype("float")
    return calib_frame

def get_dmdtda(gdir, calib_data):
    dhdt = calib_data["dh"].mean()
    
    da = gdir.rgi_area_km2
    dmdtda = dhdt * cfg.PARAMS["ice_density"] * da / 1e6
    return dmdtda


def get_geodetic_mb_from_dataset(gdir, ds, calendar: bool = False, year_start=2011, year_end=2020) -> pd.DataFrame:
    calib_data = get_dhdt_data(ds, calendar=calendar, year_start=year_start, year_end=year_end)
    dmdtda = get_dmdtda(gdir, calib_data)
    dates = calib_data.index
    geodetic_mb_period = (
        f"{dates[0].strftime('%Y-%m-%d')}_{dates[-1].strftime('%Y-%m-%d')}"
    )
    geodetic_mb = {
        "rgiid": [gdir.rgi_id],
        "period": geodetic_mb_period,
        "area": gdir.rgi_area_m2,
        "dmdtda": dmdtda,
        "err_dmdtda": 0.0,
        "reg": 6,
        "is_cor": False,
    }

    return pd.DataFrame.from_records(geodetic_mb, index="rgiid")


def get_geodetic_mb_for_calibration(gdir, ds):
    pd_geodetic = utils.get_geodetic_mb_dataframe()
    for x in [True, False]:
        geodetic_mb = get_geodetic_mb_from_dataset(gdir, ds, calendar=x)
        pd_geodetic = pd.concat([pd_geodetic, geodetic_mb])
    geodetic_mb = get_geodetic_mb_from_dataset(gdir, ds, calendar=True, year_start=2015, year_end=2016)
    pd_geodetic = pd.concat([pd_geodetic, geodetic_mb])
    return pd_geodetic

# %%
geomb = get_geodetic_mb_for_calibration(gdir=gdir, ds=ds)
geomb.loc[gdir.rgi_id]
# Out:
#                                period          area    dmdtda  err_dmdtda  \
# rgiid
# RGI60-06.00377  2000-01-01_2010-01-01  1.428724e+09 -0.759900      0.1224
# RGI60-06.00377  2000-01-01_2020-01-01  1.428724e+09 -0.632600      0.0677
# RGI60-06.00377  2010-01-01_2020-01-01  1.428724e+09 -0.505300      0.1055
# RGI60-06.00377  2010-12-30_2020-01-12  1.428724e+09  0.867883      0.0000
# RGI60-06.00377  2010-09-01_2020-08-09  1.428724e+09  0.846641      0.0000
# RGI60-06.00377  2015-01-08_2016-01-03  1.428724e+09  1.094005      0.0000
#
#                 reg  is_cor
# rgiid
# RGI60-06.00377    6   False
# RGI60-06.00377    6   False
# RGI60-06.00377    6   False
# RGI60-06.00377    6   False
# RGI60-06.00377    6   False
# RGI60-06.00377    6   False

# %% [markdown]
# ### Load the calibration data

# %%
# Default calibration domain
heights, widths = gdir.get_inversion_flowline_hw()
fls = gdir.read_pickle("inversion_flowlines")
period = (1979, 2019)
years = np.arange(period[0], period[1] + 1)
cryotempo_dates = [datetime.datetime.fromtimestamp(t, tz=UTC) for t in ds.t.values]
pd_geodetic = get_geodetic_mb_for_calibration(gdir=gdir, ds=ds)

# Store results
mb_model_calib = {}
mb_model_flowlines = {}
smb_daily = {}
smb_annual = {}

# %% [markdown]
# ### Typical Workflow
#
# It's good practice to avoid overwriting the default ``mb_calib.json`` file when running calibration tests, especially when mixing different mass balance model classes. Use the ``filesuffix`` and ``mb_params_filesuffix`` arguments to ensure that the calibrated parameters are written to and read from a separate file.

# %% [markdown]
# Use ``get_specific_mb_daily`` for data at daily resolution.
# For clarity, define a generic calibration function for different mass balance models:

# %%
def get_calibrated_models(
    gdir,
    model_class,
    ref_mb,
    geodetic_period: str = "",
    years=None,
    model_calib=None,
    model_flowlines=None,
    smb=None,
    daily=False,
    calibration_filesuffix="",
    extra_model_kwargs=None,
):
    """Get calibrated models.

    Note this uses all three calibration parameters, with ``prcp_fac``
    as the first parameter.

    Parameters
    ----------
    gdir : oggm.GlacierDirectory
        Glacier directory
    model_class : oggm.MassBalanceModel
        Any mass balance model that subclasses MonthlyTIModel.
    ref_mb : pd.DataFrame
        Reference mass balance.
    geodetic_period : str, default empty string
        The reference calibration period in the format: "Y-M-D_Y-M-D"
    years : list, default None
        Years for which to calculate the specific mass balance. Ensure
        these are float years when using ``MonthlyTI``.
    model_calib : dict
        Store calibrated models derived from ``mb_model_class``
    model_flowlines : dict
        Store calibrated ``MultipleFlowlineMassBalanceModel``.
    smb : dict
        Store specific mass balance.
    daily : bool, default False
        Process daily specific mass balance.
    calibration_filesuffix : str, default empty string
        Calibration filesuffix

    Returns
    -------
    tuple
        Calibrated model instances for each calibration parameter,
        calibrated flowline models for each parameter,
        and specific mass balance for each calibrated flowline model.
    """
    model_name = model_class.__name__
    if not geodetic_period:
        geodetic_period = cfg.PARAMS["geodetic_mb_period"]

    if not daily:
        baseline_climate_suffix = ""
    else:
        baseline_climate_suffix = "_daily"

    if model_calib is None:
        model_calib = {}
    if model_flowlines is None:
        model_flowlines = {}
    if smb is None:
        smb = {}

    if not calibration_filesuffix:
        calibration_filesuffix = f"{model_name}_{geodetic_period}"
    model_key = calibration_filesuffix.removesuffix("Model")

    # This follows mb_calibration_from_geodetic_mb
    prcp_fac = massbalance.decide_winter_precip_factor(gdir)
    mi, ma = cfg.PARAMS["prcp_fac_min"], cfg.PARAMS["prcp_fac_max"]
    prcp_fac_min = utils.clip_scalar(prcp_fac * 0.8, mi, ma)
    prcp_fac_max = utils.clip_scalar(prcp_fac * 1.2, mi, ma)

    massbalance.mb_calibration_from_scalar_mb(
        gdir,
        ref_mb=ref_mb,
        ref_period=geodetic_period,
        calibrate_param1="prcp_fac",
        calibrate_param2="melt_f",
        calibrate_param3="temp_bias",
        prcp_fac=prcp_fac,
        prcp_fac_min=prcp_fac_min,
        prcp_fac_max=prcp_fac_max,
        mb_model_class=model_class,
        overwrite_gdir=True,
        use_2d_mb=False,
        baseline_climate_suffix=baseline_climate_suffix,
        filesuffix=calibration_filesuffix,
        extra_model_kwargs=extra_model_kwargs,
    )

    if not extra_model_kwargs:
        model_calib[model_key] = model_class(
            gdir, mb_params_filesuffix=calibration_filesuffix
        )
    else:
        model_calib[model_key] = model_class(
            gdir, mb_params_filesuffix=calibration_filesuffix, **extra_model_kwargs
        )
    model_flowlines[model_key] = massbalance.MultipleFlowlineMassBalance(
        gdir,
        mb_model_class=model_class,
        use_inversion_flowlines=True,
        mb_params_filesuffix=calibration_filesuffix,
    )
    fls = gdir.read_pickle("inversion_flowlines")
    if not years:
        years = np.arange(1979, 2020)
    if not daily:
        smb[model_key] = model_flowlines[model_key].get_specific_mb(fls=fls, year=years)
    else:
        smb[model_key] = model_flowlines[model_key].get_specific_mb_daily(
            fls=fls, year=years
        )

    return model_calib, model_flowlines, smb

# %% [markdown]
# Calibrate OGGM using the following parameters:
# | Model Type | Calibration Dataset           | Calibration Period  |
# | ------------- | ------------- | ----- |
# | Monthly TI | Hugonnet | 2000-2020 |
# | Monthly TI | CryoTEMPO-EOLIS | 2000-2020 |
# | Daily TI  | CryoTEMPO-EOLIS | 2011-2020 |
# | Daily TI, Surface Tracking  | CryoTEMPO-EOLIS | 2011-2020 |
# | Daily TI, Surface Tracking  | CryoTEMPO-EOLIS | 2015 |

# %%
sfc_model_kwargs = {
    "resolution": "day",
    "gradient_scheme": "annual",
    "check_data_exists": False,
}
model_matrix = {
    "Monthly_Hugonnet" : {"model": massbalance.MonthlyTIModel, "geo_period":"2000-01-01_2020-01-01", "daily":False},
    "Monthly_Cryosat" : {"model": massbalance.MonthlyTIModel, "geo_period":"2010-12-30_2020-01-12", "daily":False},
    "Daily_Cryosat" : {"model": massbalance.DailyTIModel, "geo_period":"2010-12-30_2020-01-12", "daily":True},
    "DailySfc_Cryosat" : {"model": massbalance.DailySfcTIModel, "geo_period":"2010-12-30_2020-01-12", "daily":True, "extra_kwargs":sfc_model_kwargs},
    "DailySfc_Cryosat_2015" : {"model": massbalance.DailySfcTIModel, "geo_period":"2015-01-08_2016-01-03", "daily":True, "extra_kwargs":sfc_model_kwargs},
}


for matrix_name, model_params in model_matrix.items():
    daily = model_params["daily"]
    mb_model_class = model_params["model"]
    geo_period = model_params["geo_period"]
    calibration_filesuffix = f"{matrix_name}_{geo_period}"
    cfg.PARAMS["geodetic_mb_period"] = geo_period
    mb_geodetic = (
        pd_geodetic.loc[pd_geodetic.period == geo_period].loc[gdir.rgi_id].dmdtda
        * 1000
    )

    mb_model_calib, mb_model_flowlines, smb_daily = get_calibrated_models(
            gdir=gdir,
            model_class=mb_model_class,
            ref_mb=mb_geodetic,
            geodetic_period=cfg.PARAMS["geodetic_mb_period"],
            model_calib=mb_model_calib,
            model_flowlines=mb_model_flowlines,
            smb=smb_daily,
            daily=daily,
            calibration_filesuffix=calibration_filesuffix,
            extra_model_kwargs=model_params.get("extra_kwargs", None)
        )
    gdir.read_json("mb_calib", filesuffix=calibration_filesuffix)
    uncertainties = datacube_calib.get_calibration_uncertainties(
            gdir, calibration_filesuffix
        )
# Out:
# 2025-06-16 23:36:19: oggm.cfg: PARAMS['geodetic_mb_period'] changed from `2000-01-01_2020-01-01` to `2010-12-30_2020-01-12`.
# Reference MB: -632.6 kg m-2
# Reference MB Uncertainties: None kg m-2
# Reference MB Time Period: 2000-01-01_2020-01-01
#
# Reference MB: 867.883490192389 kg m-2
# Reference MB Uncertainties: None kg m-2
# Reference MB Time Period: 2010-12-30_2020-01-12
#
# Reference MB: 867.883490192389 kg m-2
# Reference MB Uncertainties: None kg m-2
# Reference MB Time Period: 2010-12-30_2020-01-12
# /home/nicolas/PycharmProjects/OGGM/oggm-gampnico/oggm/core/massbalance.py:3212: UserWarning: be cautious when using get_daily_mb and test yourself if it does what you expect
#   warnings.warn('be cautious when using get_daily_mb and test yourself if it does '
# 2025-06-16 23:36:20: oggm.cfg: PARAMS['geodetic_mb_period'] changed from `2010-12-30_2020-01-12` to `2015-01-08_2016-01-03`.
# ...

# %% [markdown]
# Let's make sure the calibration was applied successfully.

# %%
for matrix_name, model_params in model_matrix.items():
    print(matrix_name)
    datacube_calib.get_calibrated_results(
            gdir, mb_calib_suffix=f"{matrix_name}_{model_params['geo_period']}"
        )
# Out:
# Monthly_Hugonnet
# melt_f: 5.0
# prcp_fac: 2.5636527670401104
# temp_bias: 0
#
# Monthly_Cryosat
# melt_f: 3.134025373636785
# prcp_fac: 2.7176440628347813
# temp_bias: 0
#
# Daily_Cryosat
# melt_f: 2.2033890796904445
# prcp_fac: 2.7176440628347813
# temp_bias: 0
#
# DailySfc_Cryosat
# melt_f: 3.964181795691891
# prcp_fac: 2.7176440628347813
# temp_bias: 0
#
# DailySfc_Cryosat_2015
# melt_f: 3.9374807926966797
# prcp_fac: 2.7176440628347813
# temp_bias: 0

# %% [markdown]
# If you have ``holoviews`` installed, create an interactive plot to visualise this.

# %%
float_years = [utils.date_to_floatyear(i.year, i.month) for i in pd.date_range(f"{years[0]}-01-01", f"{years[-1]}-12-31", freq="1MS")]
for matrix_name, model_params in model_matrix.items():
    if "Monthly" in matrix_name:
        mb_mod = mb_model_flowlines[f"{matrix_name}_{model_params['geo_period']}"]
        fls = gdir.read_pickle("inversion_flowlines")
        smb_monthly = mb_mod.get_specific_mb_monthly(fls=fls, year=float_years)
        smb_daily[f"{matrix_name}_month_{model_params['geo_period']}"] = smb_monthly

# %%
importlib.reload(oggm_plot)
layout = oggm_plot.plot_cumulative_smb_lps(smb=smb_daily, years=years, glacier_name=gdir.name)
layout
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a619613e-a909-4fad-afec-88653cfa9833'>
#   <div id="fb072cf8-f18a-4dac-9207-b510b9b89c09" data-root-id="a619613e-a909-4fad-afec-88653cfa9833" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
importlib.reload(oggm_plot)
layout = oggm_plot.plot_mass_balance_lps(smb=smb_daily, years=years, glacier_name=gdir.name, datacube=ds, gdir=gdir
)
layout
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='ed7ed0ba-b90c-40de-9b3d-a58491b268c1'>
#   <div id="b056a32d-df59-41a8-a0a1-8a9ad116e532" data-root-id="ed7ed0ba-b90c-40de-9b3d-a58491b268c1" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...
